# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 853.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('alzheimer')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0                                                 []       Homo sapiens
# 1  [{'xref_id': 'Q92542', 'xref_name': None, 'xre...       Homo sapiens
# 2                                                 []       Homo sapiens
# 3                                                 []  Rattus norvegicus
# 4                                                 []       Mus musculus
# 5  [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
#
#                                    pref_name  score  species_group_flag  \
# 0  Nucleosome-remodeling factor subunit BPTF   13.0               False
# 1                                  Nicastrin   11.0               False
# 2                            Gamma-secretase   11.0               False
# 3                    Amyloid beta A4 protein    9.0               False
# 4                    Amyloid-beta A4 protein    8.0               False
# ...

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL2487'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1562  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1564  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1566  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
! cp bioactivity_data.csv "/content/drive/MyDrive/Colab Notebooks/data_alzheimer"

# %%
! ls -l "/content/drive/MyDrive/Colab Notebooks/data_alzheimer"
# Out:
# total 1030
# -rw------- 1 root root 1054260 Jul 30 18:31 bioactivity_data.csv

# %%
# !ls
# Out:
# bioactivity_data.csv  drive  sample_data

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1562  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1564  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1566  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles','bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1388      CHEMBL5174252  O=[N+]([O-])c1ccc2nc3c(c(Nc4[nH]nc5ncccc45)c2c...
# 1389      CHEMBL5205489  Nc1nn(-c2c3c(nc4ccc([N+](=O)[O-])cc24)CCCC3)c2...
# 1390      CHEMBL5190530                      Cc1ccc2nc3c(c(NCCO)c2c1)CCCC3
# 1391      CHEMBL5199187               Cc1ccc2nc3c(c(NCCN4CCOCC4)c2c1)CCCC3
# 1392      CHEMBL5185354            CC(=O)Nc1ccc2nc3c(c(N4CCCCC4)c2c1)CCCC3
#
#      bioactivity_class standard_value
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
# !ls -l
# Out:
# total 1160
# -rw-r--r-- 1 root root 1054260 Jul 30 18:30 bioactivity_data.csv
# -rw-r--r-- 1 root root  119141 Jul 30 18:34 bioactivity_preprocessed_data.csv
# drwx------ 5 root root    4096 Jul 30 18:29 drive
# drwxr-xr-x 1 root root    4096 Jul 27 13:37 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/drive/MyDrive/Colab Notebooks/data_alzheimer"

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/data_alzheimer"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
